# %%
import numpy as np
import pandas as pd

# %%
8
# Out:
# 8

# %%
pip install matplotlib

# %%
pip install pypolt
# Out:
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Could not find a version that satisfies the requirement pypolt (from versions: none)
# ERROR: No matching distribution found for pypolt

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %%
Bodyfat=pd.read_csv('C:/Users/ELCOT/OneDrive/Desktop/bodyfat.csv')

# %%
Bodyfat
# Out:
#      Density  BodyFat  Age  Weight  Height  Neck  Chest  Abdomen    Hip  \
# 0     1.0708     12.3   23  154.25   67.75  36.2   93.1     85.2   94.5
# 1     1.0853      6.1   22  173.25   72.25  38.5   93.6     83.0   98.7
# 2     1.0414     25.3   22  154.00   66.25  34.0   95.8     87.9   99.2
# 3     1.0751     10.4   26  184.75   72.25  37.4  101.8     86.4  101.2
# 4     1.0340     28.7   24  184.25   71.25  34.4   97.3    100.0  101.9
# ..       ...      ...  ...     ...     ...   ...    ...      ...    ...
# 247   1.0736     11.0   70  134.25   67.00  34.9   89.2     83.6   88.8
# 248   1.0236     33.6   72  201.00   69.75  40.9  108.5    105.0  104.5
# 249   1.0328     29.3   72  186.75   66.00  38.9  111.1    111.5  101.7
# 250   1.0399     26.0   72  190.75   70.50  38.9  108.3    101.3   97.8
# 251   1.0271     31.9   74  207.50   70.00  40.8  112.4    108.5  107.1
#
#      Thigh  Knee  Ankle  Biceps  Forearm  Wrist
# 0     59.0  37.3   21.9    32.0     27.4   17.1
# ...

# %%
Bodyfat.shape
# Out:
# (252, 15)

# %%
Bodyfat.tail()
# Out:
#      Density  BodyFat  Age  Weight  Height  Neck  Chest  Abdomen    Hip  \
# 247   1.0736     11.0   70  134.25   67.00  34.9   89.2     83.6   88.8
# 248   1.0236     33.6   72  201.00   69.75  40.9  108.5    105.0  104.5
# 249   1.0328     29.3   72  186.75   66.00  38.9  111.1    111.5  101.7
# 250   1.0399     26.0   72  190.75   70.50  38.9  108.3    101.3   97.8
# 251   1.0271     31.9   74  207.50   70.00  40.8  112.4    108.5  107.1
#
#      Thigh  Knee  Ankle  Biceps  Forearm  Wrist
# 247   49.6  34.8   21.5    25.6     25.7   18.5
# 248   59.6  40.8   23.2    35.2     28.6   20.1
# 249   60.3  37.3   21.5    31.3     27.2   18.0
# 250   56.0  41.6   22.7    30.5     29.4   19.8
# 251   59.3  42.2   24.6    33.7     30.0   20.9

# %%
Bodyfat.head()
# Out:
#    Density  BodyFat  Age  Weight  Height  Neck  Chest  Abdomen    Hip  Thigh  \
# 0   1.0708     12.3   23  154.25   67.75  36.2   93.1     85.2   94.5   59.0
# 1   1.0853      6.1   22  173.25   72.25  38.5   93.6     83.0   98.7   58.7
# 2   1.0414     25.3   22  154.00   66.25  34.0   95.8     87.9   99.2   59.6
# 3   1.0751     10.4   26  184.75   72.25  37.4  101.8     86.4  101.2   60.1
# 4   1.0340     28.7   24  184.25   71.25  34.4   97.3    100.0  101.9   63.2
#
#    Knee  Ankle  Biceps  Forearm  Wrist
# 0  37.3   21.9    32.0     27.4   17.1
# 1  37.3   23.4    30.5     28.9   18.2
# 2  38.9   24.0    28.8     25.2   16.6
# 3  37.3   22.8    32.4     29.4   18.2
# 4  42.2   24.0    32.2     27.7   17.7

# %%
fat=Bodyfat.drop(['Neck','Chest','Density','Abdomen','Hip','Thigh','Knee','Ankle','Biceps','Forearm','Wrist'],axis=1)

# %%
fat
# Out:
#      BodyFat  Age  Weight  Height
# 0       12.3   23  154.25   67.75
# 1        6.1   22  173.25   72.25
# 2       25.3   22  154.00   66.25
# 3       10.4   26  184.75   72.25
# 4       28.7   24  184.25   71.25
# ..       ...  ...     ...     ...
# 247     11.0   70  134.25   67.00
# 248     33.6   72  201.00   69.75
# 249     29.3   72  186.75   66.00
# 250     26.0   72  190.75   70.50
# 251     31.9   74  207.50   70.00
#
# [252 rows x 4 columns]

# %%
x=fat.iloc[:,0].values.reshape(-1,1)
y=fat.iloc[:,-1].values.reshape(-1,1)

# %%
x
# Out:
# array([[12.3],
#        [ 6.1],
#        [25.3],
#        [10.4],
#        [28.7],
#        [20.9],
#        [19.2],
#        [12.4],
#        [ 4.1],
#        [11.7],
#        [ 7.1],
#        [ 7.8],
#        [20.8],
#        [21.2],
#        [22.1],
#        [20.9],
#        [29. ],
#        [22.9],
#        [16. ],
#        [16.5],
#        [19.1],
#        [15.2],
#        [15.6],
#        [17.7],
#        [14. ],
#        [ 3.7],
#        [ 7.9],
#        [22.9],
#        [ 3.7],
#        [ 8.8],
#        [11.9],
#        [ 5.7],
#        [11.8],
#        [21.3],
#        [32.3],
#        [40.1],
#        [24.2],
#        [28.4],
#        [35.2],
#        [32.6],
#        [34.5],
#        [32.9],
#        [31.6],
#        [32. ],
#        [ 7.7],
#        [13.9],
#        [10.8],
#        [ 5.6],
#        [13.6],
#        [ 4. ],
#        [10.2],
#        [ 6.6],
#        [ 8. ],
#        [ 6.3],
#        [ 3.9],
#        [22.6],
#        [20.4],
#        [28. ],
# ...

# %%
y
# Out:
# array([[67.75],
#        [72.25],
#        [66.25],
#        [72.25],
#        [71.25],
#        [74.75],
#        [69.75],
#        [72.5 ],
#        [74.  ],
#        [73.5 ],
#        [74.5 ],
#        [76.  ],
#        [69.5 ],
#        [71.25],
#        [69.5 ],
#        [66.  ],
#        [71.  ],
#        [71.  ],
#        [67.75],
#        [73.5 ],
#        [68.  ],
#        [69.75],
#        [68.25],
#        [70.  ],
#        [67.75],
#        [71.5 ],
#        [67.5 ],
#        [67.5 ],
#        [64.75],
#        [69.  ],
#        [73.75],
#        [71.25],
#        [71.25],
#        [71.  ],
#        [73.5 ],
#        [65.  ],
#        [70.  ],
#        [68.25],
#        [72.25],
#        [67.  ],
#        [68.75],
#        [29.5 ],
#        [70.  ],
#        [71.5 ],
#        [68.  ],
#        [73.25],
#        [67.5 ],
#        [71.25],
#        [68.5 ],
#        [66.75],
#        [72.25],
#        [69.  ],
#        [67.75],
#        [73.5 ],
#        [67.5 ],
# ...

# %%
plt.scatter(x,y)
plt.xlabel('bodyfat')
plt.ylabel('Weight')
plt.show()

# %%
pip install sklearn

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test= train_test_split(x,y,test_size=0.2,random_state=0)

# %%
x_train.shape
# Out:
# (201, 1)

# %%
x_test.shape
# Out:
# (51, 1)

# %%
y_train.shape
# Out:
# (201, 1)

# %%
y_test.shape
# Out:
# (51, 1)

# %%
from sklearn.linear_model import LinearRegression

# %%
ln=LinearRegression()

# %%
ln
# Out:
# LinearRegression()

# %%
ln.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_predict=ln.predict(x_test)

# %%
check=pd.DataFrame(x_test,columns=['Bodyfat'])

# %%
check
# Out:
#     Bodyfat
# 0      12.5
# 1      27.0
# 2       3.0
# 3      20.4
# 4       9.4
# 5      23.6
# 6      25.8
# 7      25.2
# 8      25.8
# 9      27.1
# 10     25.2
# 11     15.4
# 12     21.4
# 13     20.5
# 14     16.5
# 15     13.5
# 16     16.6
# 17      0.7
# 18     10.0
# 19     11.3
# 20     20.4
# 21     13.9
# 22     29.9
# 23     22.4
# 24     19.7
# 25     31.9
# 26      4.1
# 27     22.6
# 28     22.0
# 29     28.4
# 30     30.2
# 31     27.2
# 32     28.0
# 33     11.5
# 34     34.3
# 35     14.2
# 36     23.6
# 37     20.9
# 38     15.6
# 39     11.4
# 40     17.5
# 41     20.8
# 42     34.8
# 43     22.5
# 44     20.5
# 45     14.9
# 46     12.4
# 47      7.7
# 48     32.3
# 49      0.0
# 50      8.8

# %%
check['actual Weight']=y_test

# %%
check[' Weight Predicted']=y_predict

# %%
check
# Out:
#     Bodyfat  actual Weight   Weight Predicted
# 0      12.5          68.75          70.663118
# 1      27.0          70.00          69.747124
# 2       3.0          67.75          71.263252
# 3      20.4          72.00          70.164059
# 4       9.4          69.00          70.858951
# 5      23.6          67.50          69.961909
# 6      25.8          74.00          69.822931
# 7      25.2          74.25          69.860834
# 8      25.8          67.00          69.822931
# 9      27.1          69.75          69.740807
# 10     25.2          70.25          69.860834
# 11     15.4          71.50          70.479919
# 12     21.4          69.25          70.100888
# 13     20.5          72.50          70.157742
# 14     16.5          67.25          70.410430
# 15     13.5          64.00          70.599946
# 16     16.6          73.00          70.404113
# 17      0.7          65.50          71.408547
# 18     10.0          72.25          70.821048
# ...

# %%
plt.scatter(x,y,color='blue')
plt.plot(x_test,y_predict,color='red')
plt.show()

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

# %%
mean_squared_error(y_test,y_predict)
# Out:
# 6.705932501579664

# %%
mean_absolute_error(y_test,y_predict)
# Out:
# 2.0800303464201995

# %%
r2_score(y_test,y_predict)
# Out:
# -0.16941589558396308
